# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
import numpy as np

# %%
car = pd.read_csv("I:/ML Projects/Car-Price-Predictor-ML-Project/model training/car_data.csv")

# %%
car.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %%
car.describe()
# Out:
#               name company  year          Price  kms_driven fuel_type
# count          892     892   892            892         840       837
# unique         525      48    61            274         258         3
# top     Honda City  Maruti  2015  Ask For Price  45,000 kms    Petrol
# freq            13     235   117             35          30       440

# %%
car['year'].unique()
# Out:
# array(['2007', '2006', '2018', '2014', '2015', '2012', '2013', '2016',
#        '2010', '2017', '2008', '2011', '2019', '2009', '2005', '2000',
#        '...', '150k', 'TOUR', '2003', 'r 15', '2004', 'Zest', '/-Rs',
#        'sale', '1995', 'ara)', '2002', 'SELL', '2001', 'tion', 'odel',
#        '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi', 'car', 'able', 'no.',
#        'd...', 'SALE', 'digo', 'sell', 'd Ex', 'n...', 'e...', 'D...',
#        ', Ac', 'go .', 'k...', 'o c4', 'zire', 'cent', 'Sumo', 'cab',
#        't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
car['Price'].unique()
# Out:
# array(['80,000', '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', '75,000', '1,00,000',
#        '2,90,000', '95,000', '1,80,000', '3,85,000', '1,05,000',
#        '6,50,000', '6,89,999', '4,48,000', '5,49,000', '5,01,000',
#        '4,89,999', '2,80,000', '3,49,999', '2,84,999', '3,45,000',
#        '4,99,999', '2,35,000', '2,49,999', '14,75,000', '3,95,000',
#        '2,20,000', '1,70,000', '85,000', '2,00,000', '5,70,000',
#        '1,10,000', '4,48,999', '18,91,111', '1,59,500', '3,44,999',
#        '4,49,999', '8,65,000', '6,99,000', '3,75,000', '2,24,999',
#        '12,00,000', '1,95,000', '3,51,000', '2,40,000', '90,000',
#        '1,55,000', '6,00,000', '1,89,500', '2,10,000', '3,90,000',
#        '1,35,000', '16,00,000', '7,01,000', '2,65,000', '5,25,000',
#        '3,72,000', '6,35,000', '5,50,000', '4,85,000', '3,29,500',
#        '2,51,111', '5,69,999', '69,999', '2,99,999', '3,99,999',
#        '4,50,000', '2,70,000', '1,58,400', '1,79,000', '1,25,000',
#        '2,99,000', '1,50,000', '2,75,000', '2,85,000', '3,40,000',
#        '70,000', '2,89,999', '8,49,999', '7,49,999', '2,74,999',
#        '9,84,999', '5,99,999', '2,44,999', '4,74,999', '2,45,000',
#        '1,69,500', '3,70,000', '1,68,000', '1,45,000', '98,500',
#        '2,09,000', '1,85,000', '9,00,000', '6,99,999', '1,99,999',
#        '5,44,999', '1,99,000', '5,40,000', '49,000', '7,00,000', '55,000',
#        '8,95,000', '3,55,000', '5,65,000', '3,65,000', '40,000',
#        '4,00,000', '3,30,000', '5,80,000', '3,79,000', '2,19,000',
#        '5,19,000', '7,30,000', '20,00,000', '21,00,000', '14,00,000',
#        '3,11,000', '8,55,000', '5,35,000', '1,78,000', '3,00,000',
#        '2,55,000', '5,49,999', '3,80,000', '57,000', '4,10,000',
#        '2,25,000', '1,20,000', '59,000', '5,99,000', '6,75,000', '72,500',
#        '6,10,000', '2,30,000', '5,20,000', '5,24,999', '4,24,999',
#        '6,44,999', '5,84,999', '7,99,999', '4,44,999', '6,49,999',
#        '9,44,999', '5,74,999', '3,74,999', '1,30,000', '4,01,000',
#        '13,50,000', '1,74,999', '2,39,999', '99,999', '3,24,999',
#        '10,74,999', '11,30,000', '1,49,000', '7,70,000', '30,000',
#        '3,35,000', '3,99,000', '65,000', '1,69,999', '1,65,000',
#        '5,60,000', '9,50,000', '7,15,000', '45,000', '9,40,000',
#        '1,55,555', '15,00,000', '4,95,000', '8,00,000', '12,99,000',
#        '5,30,000', '14,99,000', '32,000', '4,05,000', '7,60,000',
#        '7,50,000', '4,19,000', '1,40,000', '15,40,000', '1,23,000',
#        '4,98,000', '4,80,000', '4,88,000', '15,25,000', '5,48,900',
#        '7,25,000', '99,000', '52,000', '28,00,000', '4,99,000',
#        '3,81,000', '2,78,000', '6,90,000', '2,60,000', '90,001',
#        '1,15,000', '15,99,000', '1,59,000', '51,999', '2,15,000',
#        '35,000', '11,50,000', '2,69,000', '60,000', '4,30,000',
#        '85,00,003', '4,01,919', '4,90,000', '4,24,000', '2,05,000',
#        '5,49,900', '3,71,500', '4,35,000', '1,89,700', '3,89,700',
#        '3,60,000', '2,95,000', '1,14,990', '10,65,000', '4,70,000',
#        '48,000', '1,88,000', '4,65,000', '1,79,999', '21,90,000',
#        '23,90,000', '10,75,000', '4,75,000', '10,25,000', '6,15,000',
#        '19,00,000', '14,90,000', '15,10,000', '18,50,000', '7,90,000',
#        '17,25,000', '12,25,000', '68,000', '9,70,000', '31,00,000',
#        '8,99,000', '88,000', '53,000', '5,68,500', '71,000', '5,90,000',
#        '7,95,000', '42,000', '1,89,000', '1,62,000', '35,999',
#        '29,00,000', '39,999', '50,500', '5,10,000', '8,60,000',
#        '5,00,001'], dtype=object)

# %%
car.kms_driven.unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
#        '33,333 kms', '33,600 kms', '5,600 kms', '7,500 kms', '26,000 kms',
#        '24,330 kms', '65,480 kms', '28,028 kms', '2,00,000 kms',
#        '99,000 kms', '2,800 kms', '21,000 kms', '11,000 kms',
#        '66,000 kms', '3,000 kms', '7,000 kms', '38,500 kms', '37,200 kms',
#        '43,200 kms', '24,800 kms', '45,872 kms', '40,000 kms',
#        '11,400 kms', '97,200 kms', '52,000 kms', '31,000 kms',
#        '1,75,430 kms', '37,000 kms', '65,000 kms', '3,350 kms',
#        '75,000 kms', '62,000 kms', '73,000 kms', '2,200 kms',
#        '54,870 kms', '34,580 kms', '97,000 kms', '60 kms', '80,200 kms',
#        '3,200 kms', '0,000 kms', '5,000 kms', '588 kms', '71,200 kms',
#        '1,75,400 kms', '9,300 kms', '56,758 kms', '10,000 kms',
#        '56,450 kms', '56,000 kms', '32,700 kms', '9,000 kms', '73 kms',
#        '1,60,000 kms', '84,000 kms', '58,559 kms', '57,000 kms',
#        '1,70,000 kms', '80,000 kms', '6,821 kms', '23,000 kms',
#        '34,000 kms', '1,800 kms', '4,00,000 kms', '48,000 kms',
#        '90,000 kms', '12,000 kms', '69,900 kms', '1,66,000 kms',
#        '122 kms', '0 kms', '24,000 kms', '36,469 kms', '7,800 kms',
#        '24,695 kms', '15,141 kms', '59,910 kms', '1,00,000 kms',
#        '4,500 kms', '1,29,000 kms', '300 kms', '1,31,000 kms',
#        '1,11,111 kms', '59,466 kms', '25,500 kms', '44,005 kms',
#        '2,110 kms', '43,222 kms', '1,00,200 kms', '65 kms',
#        '1,40,000 kms', '1,03,553 kms', '58,000 kms', '1,20,000 kms',
#        '49,800 kms', '100 kms', '81,876 kms', '6,020 kms', '55,700 kms',
#        '18,500 kms', '1,80,000 kms', '53,000 kms', '35,500 kms',
#        '22,134 kms', '1,000 kms', '8,500 kms', '87,000 kms', '6,000 kms',
#        '15,574 kms', '8,000 kms', '55,800 kms', '56,400 kms',
#        '72,160 kms', '11,500 kms', '1,33,000 kms', '2,000 kms',
#        '88,000 kms', '65,422 kms', '1,17,000 kms', '1,50,000 kms',
#        '10,750 kms', '6,800 kms', '5 kms', '9,800 kms', '57,923 kms',
#        '30,201 kms', '6,200 kms', '37,518 kms', '24,652 kms', '383 kms',
#        '95,000 kms', '3,528 kms', '52,500 kms', '47,900 kms',
#        '52,800 kms', '1,95,000 kms', '48,008 kms', '48,247 kms',
#        '9,400 kms', '64,000 kms', '2,137 kms', '10,544 kms', '49,500 kms',
#        '1,47,000 kms', '90,001 kms', '48,006 kms', '74,000 kms',
#        '85,000 kms', '29,500 kms', '39,700 kms', '67,000 kms',
#        '19,336 kms', '60,105 kms', '45,933 kms', '1,02,563 kms',
#        '28,600 kms', '41,800 kms', '1,16,000 kms', '42,590 kms',
#        '7,400 kms', '54,500 kms', '76,000 kms', '00 kms', '11,523 kms',
#        '38,600 kms', '95,500 kms', '37,458 kms', '85,960 kms',
#        '12,516 kms', '30,600 kms', '2,550 kms', '62,500 kms',
#        '69,000 kms', '28,400 kms', '68,485 kms', '3,500 kms',
#        '85,455 kms', '63,000 kms', '1,600 kms', '77,000 kms',
#        '26,500 kms', '2,875 kms', '13,900 kms', '1,500 kms', '2,450 kms',
#        '1,625 kms', '33,400 kms', '60,123 kms', '38,900 kms',
#        '1,37,495 kms', '91,200 kms', '1,46,000 kms', '1,00,800 kms',
#        '2,100 kms', '2,500 kms', '1,32,000 kms', 'Petrol'], dtype=object)

# %%
car.fuel_type.unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %% [markdown]
# # Data Quality
#
# - year has many non-year values
# - year object to int
# - price has 'Ask for price'
# - price object to int
# - kms_driven has 'kms' with integers
# - kms_driven object to int
# - kms_driven has nan values
# - fuel_type has nan values
# - keep first 3 words of name

# %% [markdown]
# # 1. Data Cleaning

# %%
backup= car.copy()

# %%
backup.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %% [markdown]
# ### Solve -> year has many non-year values

# %%
car.year.head()
# Out:
# 0    2007
# 1    2006
# 2    2018
# 3    2014
# 4    2014
# Name: year, dtype: object

# %%
car.year.str.isnumeric().sample(10)
# Out:
# 678    True
# 288    True
# 496    True
# 391    True
# 495    True
# 325    True
# 307    True
# 824    True
# 594    True
# 486    True
# Name: year, dtype: bool

# %%
car[car.year.str.isnumeric()].sample(10)
# Out:
#                                              name     company  year  \
# 630          Mahindra Scorpio SLX 2.6 Turbo 8 Str    Mahindra  2008
# 843                     Maruti Suzuki Alto 800 Lx      Maruti  2019
# 278                       Renault Lodgy 85 PS RXL     Renault  2018
# 858                                    Tata Manza        Tata  2015
# 79                              Mini Cooper S 1.6        Mini  2013
# 406                  Hyundai Elite i20 Sportz 1.2     Hyundai  2018
# 62                   Tata Indigo eCS LS CR4 BS IV        Tata  2017
# 439  Volkswagen Vento Highline Plus 1.5 Diesel AT  Volkswagen  2015
# 622                         Chevrolet Beat Diesel   Chevrolet  2011
# 160                        Fiat Punto Emotion 1.2        Fiat  2012
#
#          Price    kms_driven fuel_type
# 630   3,00,000    70,000 kms    Diesel
# 843   4,00,000     1,500 kms    Petrol
# 278   6,89,999    20,000 kms    Diesel
# 858   1,00,000  1,00,000 kms    Diesel
# 79   18,91,111    13,500 kms    Petrol
# 406   6,00,000     7,800 kms    Petrol
# 62    2,00,000  1,30,000 kms    Diesel
# 439   5,50,000    34,000 kms    Diesel
# 622   1,25,000    56,000 kms    Diesel
# 160   1,69,500    37,200 kms    Diesel

# %%
car = car[car.year.str.isnumeric()]

# %%
car.sample(10)
# Out:
#                                      name   company  year      Price  \
# 867                    Mahindra Quanto C4  Mahindra  2013   3,25,000
# 89        Hyundai Verna Transform SX VTVT   Hyundai  2008   1,60,000
# 305                          Honda Accord     Honda  2009   1,75,000
# 506  Maruti Suzuki Wagon R Select Variant    Maruti  2016   2,25,000
# 315                            Honda City     Honda  2015   6,44,999
# 732         Maruti Suzuki Swift Dzire VDi    Maruti  2015   4,75,000
# 257  Maruti Suzuki Eeco 5 STR WITH AC HTR    Maruti  2015   2,55,000
# 510                Jaguar XE XE Portfolio    Jaguar  2016  28,00,000
# 568                    Maruti Suzuki Alto    Maruti  2019   2,65,000
# 180                 Maruti Suzuki Wagon R    Maruti  2012   1,99,999
#
#      kms_driven fuel_type
# 867  63,000 kms    Diesel
# 89   45,000 kms    Petrol
# 305  58,559 kms    Petrol
# 506  35,500 kms    Diesel
# 315  39,000 kms    Petrol
# 732  43,000 kms    Diesel
# 257   9,300 kms    Petrol
# 510   8,500 kms    Petrol
# 568   9,800 kms    Petrol
# 180  44,000 kms    Petrol

# %% [markdown]
# ### Solve -> year object to int

# %%
car['year']=car.year.astype(int)

# %%
car['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 842 entries, 0 to 891
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 842 non-null    int32
# dtypes: int32(1)
# memory usage: 9.9 KB

# %% [markdown]
# ### Solve -> price has 'Ask for price', we need only int values

# %%
car=car[car['Price'] != "Ask For Price"]

# %%
car['Price'].sample(20)
# Out:
# 60      1,75,000
# 556     2,69,000
# 78      4,49,999
# 786       42,000
# 762     5,68,500
# 579     3,50,000
# 248     5,35,000
# 537     1,15,000
# 597       90,000
# 310     2,99,999
# 857     2,60,000
# 726     2,50,000
# 445    12,99,000
# 186     3,40,000
# 514       90,000
# 285     5,40,000
# 171     5,49,000
# 507       99,000
# 110     3,45,000
# 95      1,89,500
# Name: Price, dtype: object

# %% [markdown]
# ### Solve -> price object to int and Remobe Coma

# %% [markdown]
# coma remove

# %%
car['Price'].str.replace(',','').sample(15)
# Out:
# 625    855000
# 172    209000
# 615    290000
# 633     60000
# 827    425000
# 540    159000
# 519    375000
# 839     39999
# 828    162000
# 655    650000
# 666    140000
# 717    130000
# 607    170000
# 469    150000
# 793    365000
# Name: Price, dtype: object

# %% [markdown]
# coma remove, type change into int and store in car dataset

# %%
car['Price']=car['Price'].str.replace(',','').astype(int)

# %%
car.Price.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 819 entries, 0 to 891
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 819 non-null    int32
# dtypes: int32(1)
# memory usage: 9.6 KB

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 819 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        819 non-null    object
#  1   company     819 non-null    object
#  2   year        819 non-null    int32
#  3   Price       819 non-null    int32
#  4   kms_driven  819 non-null    object
#  5   fuel_type   816 non-null    object
# dtypes: int32(2), object(4)
# memory usage: 38.4+ KB

# %% [markdown]
# ### Solve -> kms_driven has 'kms' with integers

# %%
car['kms_driven'].sample(5)
# Out:
# 147    50,000 kms
# 517    87,000 kms
# 106    44,000 kms
# 522    25,000 kms
# 159    38,500 kms
# Name: kms_driven, dtype: object

# %% [markdown]
# split based on space

# %%
car['kms_driven']=car['kms_driven'].str.split(' ')

# %%
car.kms_driven.sample(8)
# Out:
# 541    [35,000, kms]
# 292    [30,000, kms]
# 112    [36,200, kms]
# 501     [7,000, kms]
# 297    [13,000, kms]
# 640    [48,006, kms]
# 476    [48,000, kms]
# 122    [55,000, kms]
# Name: kms_driven, dtype: object

# %% [markdown]
# we take first value of this column that means 0 number index

# %%
car['kms_driven']=car['kms_driven'].str.get(0)

# %%
car['kms_driven'].sample(7)
# Out:
# 147    50,000
# 188    38,200
# 742    42,000
# 646    74,000
# 455    35,000
# 116    51,000
# 208    34,580
# Name: kms_driven, dtype: object

# %% [markdown]
# Now remove coma (,) from this integer number

# %%
car['kms_driven'] = car['kms_driven'].str.replace(',','')

# %%
car['kms_driven'].sample(7)
# Out:
# 595     23000
# 825     42000
# 37      68000
# 18      43000
# 139    200000
# 403     46000
# 189     13000
# Name: kms_driven, dtype: object

# %% [markdown]
# but here has some problem, some values stile have string, called 'Petrol' or something. we have to remove it

# %%
car['kms_driven'].tail()
# Out:
# 886    132000
# 888     27000
# 889     40000
# 890    Petrol
# 891    Petrol
# Name: kms_driven, dtype: object

# %%
car=car[car['kms_driven'].str.isnumeric()]

# %%
car.head()
# Out:
#                                      name   company  year   Price kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000      45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000         40
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000      28000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000      36000
# 6                               Ford Figo      Ford  2012  175000      41000
#
#   fuel_type
# 0    Petrol
# 1    Diesel
# 3    Petrol
# 4    Diesel
# 6    Diesel

# %% [markdown]
# now convert into integer

# %%
car['kms_driven'] = car['kms_driven'].astype(int)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 817 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        817 non-null    object
#  1   company     817 non-null    object
#  2   year        817 non-null    int32
#  3   Price       817 non-null    int32
#  4   kms_driven  817 non-null    int32
#  5   fuel_type   816 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 35.1+ KB

# %% [markdown]
# ### Solve -> fuel_type has nan values

# %%
car['fuel_type'].isna().sum()
# Out:
# 1

# %%
car[car['fuel_type'].isna()]
# Out:
#                name company  year   Price  kms_driven fuel_type
# 132  Toyota Corolla  Toyota  2009  275000       26000       NaN

# %%
car[~car['fuel_type'].isna()].sample(7) # ~ it means, excluding this NaN rows i need all
# Out:
#                                        name     company  year   Price  \
# 759       Hyundai Verna 1.6 CRDI SX Plus AT     Hyundai  2012  600000
# 135                    Hyundai i20 Asta 1.2     Hyundai  2009  210000
# 659  Maruti Suzuki Zen Estilo LXI Green CNG      Maruti  2008  125000
# 332                         Volkswagen Polo  Volkswagen  2010  199999
# 864                      Tata Indica eV2 LS        Tata  2016   50500
# 676     Volkswagen Vento Comfortline Petrol  Volkswagen  2011  240000
# 406            Hyundai Elite i20 Sportz 1.2     Hyundai  2018  600000
#
#      kms_driven fuel_type
# 759       29000    Diesel
# 135       65480    Petrol
# 659       46000    Petrol
# 332       60000    Diesel
# 864       91200    Diesel
# 676       45933    Petrol
# 406        7800    Petrol

# %%
car=car[~car['fuel_type'].isna()]

# %%
car['fuel_type'].iloc[137]
# Out:
# 'Diesel'

# %%
car.sample(7)
# Out:
#                                      name   company  year   Price  kms_driven  \
# 627             Mahindra Scorpio 2.6 CRDe  Mahindra  2007  260000       56000
# 847                 Maruti Suzuki Alto AX    Maruti  2019  425000        1625
# 17                                Audi Q7      Audi  2014  500000       16934
# 201                     Tata Nano Cx BSIV      Tata  2013   40000        2200
# 472                  Mahindra Scorpio S10  Mahindra  2015  900000       97200
# 762                Tata Tiago Revotorq XZ      Tata  2019  568500           0
# 506  Maruti Suzuki Wagon R Select Variant    Maruti  2016  225000       35500
#
#     fuel_type
# 627    Diesel
# 847    Petrol
# 17     Diesel
# 201    Petrol
# 472    Diesel
# 762    Petrol
# 506    Diesel

# %% [markdown]
# ### Solve -> keep first 3 words of name

# %%
car['name']=car['name'].str.split(' ')

# %%
car['name'].head()
# Out:
# 0      [Hyundai, Santro, Xing, XO, eRLX, Euro, III]
# 1                      [Mahindra, Jeep, CL550, MDI]
# 3    [Hyundai, Grand, i10, Magna, 1.2, Kappa, VTVT]
# 4            [Ford, EcoSport, Titanium, 1.5L, TDCi]
# 6                                      [Ford, Figo]
# Name: name, dtype: object

# %%
car['name'] = car['name'].str.slice(0,3)

# %%
car.head()
# Out:
#                          name   company  year   Price  kms_driven fuel_type
# 0     [Hyundai, Santro, Xing]   Hyundai  2007   80000       45000    Petrol
# 1     [Mahindra, Jeep, CL550]  Mahindra  2006  425000          40    Diesel
# 3       [Hyundai, Grand, i10]   Hyundai  2014  325000       28000    Petrol
# 4  [Ford, EcoSport, Titanium]      Ford  2014  575000       36000    Diesel
# 6                [Ford, Figo]      Ford  2012  175000       41000    Diesel

# %%
car['name'] = car['name'].str.join(' ')

# %%
car.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 6               Ford Figo      Ford  2012  175000       41000    Diesel

# %% [markdown]
# #### here our index change, so now we reset our index

# %%
car=car.reset_index()

# %%
car.head()
# Out:
#    index                    name   company  year   Price  kms_driven fuel_type
# 0      0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1      1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2      3       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3      4  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4      6               Ford Figo      Ford  2012  175000       41000    Diesel

# %% [markdown]
# now drop previous index

# %%
car.drop(columns=['index'], inplace=True)

# %%
car=car.reset_index(drop=True)

# %%
car.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4               Ford Figo      Ford  2012  175000       41000    Diesel

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        816 non-null    object
#  1   company     816 non-null    object
#  2   year        816 non-null    int32
#  3   Price       816 non-null    int32
#  4   kms_driven  816 non-null    int32
#  5   fuel_type   816 non-null    object
# dtypes: int32(3), object(3)
# memory usage: 28.8+ KB

# %%
car.describe()
# Out:
#               year         Price     kms_driven
# count   816.000000  8.160000e+02     816.000000
# mean   2012.444853  4.117176e+05   46275.531863
# std       4.002992  4.751844e+05   34297.428044
# min    1995.000000  3.000000e+04       0.000000
# 25%    2010.000000  1.750000e+05   27000.000000
# 50%    2013.000000  2.999990e+05   41000.000000
# 75%    2015.000000  4.912500e+05   56818.500000
# max    2019.000000  8.500003e+06  400000.000000

# %% [markdown]
# # 2. EDA and Data Pre-Processing

# %%
car[car['Price']>500000].count()
# Out:
# name          188
# company       188
# year          188
# Price         188
# kms_driven    188
# fuel_type     188
# dtype: int64

# %%
(car['Price'] > 2000000).sum()
# Out:
# 7

# %%
car[car['Price']>700000].count()
# Out:
# name          95
# company       95
# year          95
# Price         95
# kms_driven    95
# fuel_type     95
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.hist(car['Price'], bins=30)
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(car['year'], bins=30)
plt.xlabel('year')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(car['kms_driven'], bins=30)
plt.xlabel('kms_driven')
plt.ylabel('Count')
plt.show()

# %%
plt.boxplot(car['Price'])
plt.ylabel('Price')
plt.show()

# %%
Q1 = car['Price'].quantile(0.25)
Q3 = car['Price'].quantile(0.75)
IQR = Q3 - Q1

# %%
outliers = car[
    (car['Price'] < Q1 - 1.5 * IQR) |
    (car['Price'] > Q3 + 1.5 * IQR)
]

# %%
outliers.shape[0]
# Out:
# 53

# %%
car['Price'].max()
# Out:
# 8500003

# %%
car[car['Price'] == car['Price'].max()]
# Out:
#                    name   company  year    Price  kms_driven fuel_type
# 534  Mahindra XUV500 W6  Mahindra  2014  8500003       45000    Diesel

# %%
car = car[car['Price'] != car['Price'].max()]

# %%
plt.boxplot(car['Price'])
plt.ylabel('Price')
plt.show()

# %%
car.head()
# Out:
#                      name   company  year   Price  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007   80000       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006  425000          40    Diesel
# 2       Hyundai Grand i10   Hyundai  2014  325000       28000    Petrol
# 3  Ford EcoSport Titanium      Ford  2014  575000       36000    Diesel
# 4               Ford Figo      Ford  2012  175000       41000    Diesel

# %%
car.to_csv('car_clean_data.csv')

# %% [markdown]
# # Modeling

# %%
X=car.drop(columns='Price')

# %%
Y=car['Price']

# %%
X.head()
# Out:
#                      name   company  year  kms_driven fuel_type
# 0     Hyundai Santro Xing   Hyundai  2007       45000    Petrol
# 1     Mahindra Jeep CL550  Mahindra  2006          40    Diesel
# 2       Hyundai Grand i10   Hyundai  2014       28000    Petrol
# 3  Ford EcoSport Titanium      Ford  2014       36000    Diesel
# 4               Ford Figo      Ford  2012       41000    Diesel

# %%
Y.head()
# Out:
# 0     80000
# 1    425000
# 2    325000
# 3    575000
# 4    175000
# Name: Price, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (652, 5)
# (163, 5)
# (652,)
# (163,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe=OneHotEncoder()
ohe.fit(X[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['name','company','fuel_type']),remainder='passthrough')

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#        'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#        'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat...
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Force', 'Ford',
#        'Hindustan', 'Honda', 'Hyundai', 'Jaguar', 'Jeep', 'Land',
#        'Mahindra', 'Maruti', 'Mercedes', 'Mini', 'Mitsubishi', 'Nissan',
#        'Renault', 'Skoda', 'Tata', 'Toyota', 'Volkswagen', 'Volvo'],
#       dtype=object),
#                                                                             array(['Diesel', 'LPG', 'Petrol'], dtype=object)]),
#                                                   ['name', 'company',
#                                                    'fuel_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6050581193966035

# %%
scores=[]
for i in range (1000):
    X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 433

# %%
scores[np.argmax(scores)]
# Out:
# 0.8457059012561223

# %%
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8457059012561223

# %%
import pickle

# %%
pickle.dump(pipe,open('linearregressionmodel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame(columns=['name','company','year','kms_driven','fuel_type'],data=np.array(['Maruti Suzuki Swift','Maruti',2019,100,'Petrol']).reshape(1,5)))
# Out:
# array([458894.10960853])
